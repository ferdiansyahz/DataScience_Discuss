# %%
from distutils.core import setup 
import py2exe 
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd
from pathlib import Path

setup(console=['parsing_bendungan.py'])
# Out:
# ---------------------------------------------------------------------------
# GetoptError                               Traceback (most recent call last)
# File c:\Users\P5CD1\AppData\Local\Programs\Python\Python310\lib\site-packages\setuptools\_distutils\fancy_getopt.py:244, in FancyGetopt.getopt(self, args, object)
#     243 try:
# --> 244     opts, args = getopt.getopt(args, short_opts, self.long_opts)
#     245 except getopt.error as msg:
#
# File c:\Users\P5CD1\AppData\Local\Programs\Python\Python310\lib\getopt.py:93, in getopt(args, shortopts, longopts)
#      92 if args[0].startswith('--'):
# ---> 93     opts, args = do_longs(opts, args[0][2:], longopts, args[1:])
#      94 else:
#
# File c:\Users\P5CD1\AppData\Local\Programs\Python\Python310\lib\getopt.py:157, in do_longs(opts, opt, longopts, args)
#     155     opt, optarg = opt[:i], opt[i+1:]
# --> 157 has_arg, opt = long_has_args(opt, longopts)
#     158 if has_arg:
#
# ...
