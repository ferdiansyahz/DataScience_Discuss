# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from IPython.display import display
import urllib.request
import requests

'''
url = "https://www.tideschart.com/Indonesia/Jakarta/Weekly/"
r = requests.get(url,verify=False)
#soup = BeautifulSoup(r.content, "lxml")
soup = BeautifulSoup(r.content, "html")



r = urllib.request.urlopen("https://www.tideschart.com/Indonesia/Jakarta/Weekly/")
source_code = r.read()
soup = BeautifulSoup(source_code, 'html.parser')
'''

res = requests.get("https://www.tideschart.com/Indonesia/Jakarta/Weekly/")
soup = BeautifulSoup(res.text, "html.parser")

# %%
df = pd.DataFrame(columns = [
'Hari_Tanggal',
'1st_tide',
'1st_tide_height',
'2nd_tide',
'2nd_tide_heigth'
])
display(df)
# Out:
# Empty DataFrame
# Columns: [Hari_Tanggal, 1st_tide, 1st_tide_height, 2nd_tide, 2nd_tide_heigth]
# Index: []

# %%
hari = soup.find(id="main-content").find("td", {"class": "day"})
print(hari)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 hari = soup.find(id="main-content").find("td", {"class": "day"})
#       2 print(hari)
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
#df = list()
for el in soup.find_all("div",{"class" : "container-fluid"}):
    #df.append(el.get_text("\n",strip=True).split("\n"))
    #display(el.get_text("\n",strip=True).split("\n"))
    fic = el.get_text("\n",strip=True)
    print(fic)

#df = pd.DataFrame(df)

# %%
df = list()
for el in soup.find_all("tbody"):
    df.append(el.get_text("\n",strip=True).split("\n"))
    #display(el.get_text("\n",strip=True).split("\n"))

df = pd.DataFrame(df)

# %%
display(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_01 = list()
for el in soup.find("tbody").find_all("td",{"class" : "day"}):
    fic = el.get_text("\n",strip=True)
    print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
display(df_01)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [61], line 2
#       1 df_01 = list()
# ----> 2 for el in soup.find("tbody").find_all("td",{"class" : "day"}):
#       3     fic = el.get_text("\n",strip=True)
#       4     print(fic)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
test = soup.find_all(id="main-content")
print(str(test))
# Out:
# []

# %%
#df = list()
for el in soup.find_all("div",{"class" : "container-fluid"}):
    #df.append(el.get_text("\n",strip=True).split("\n"))
    #display(el.get_text("\n",strip=True).split("\n"))
    fic = str(el)
    print(fic)

# %%
#test1 = soup.find("table",class_="table table-hover tidechart mb-4").find_all("tr")[1:]
test1 = soup.find("div",class_="wrapper-pwa")
print(str(test1))
# Out:
# None

# %%
df_01 = list()
for el in soup.find_all("div",{"class" : "container-fluid"}):
    fic = el.get_text("\n",strip=True)
    print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
display(df_01)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for post in soup.select("#ListViewInner tr"):
    print(post.get('td'))

# %%
for el in soup.find_all("div",{"class" : "container-fluid"}):
    print(el.text)

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager


url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
time.sleep(8)
driver.get(url)
time.sleep(10)

soup = BeautifulSoup(driver.page_source, 'lxml')
#driver.close()

#status = soup.find_all('div', {'class': "container-fluid"})
#para = status.find_all('td').get_text
#print(para)
for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    print(fic)
driver.close()
# Out:
# [WDM] - Downloading: 100%|██████████| 6.58M/6.58M [00:04<00:00, 1.63MB/s]
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_304\694809423.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# Tide table for Daerah Khusus Ibukota Jakarta this week
# Day
# Tide times for Daerah Khusus Ibukota Jakarta
# 1st Tide
# 2nd Tide
# 3rd Tide
# 4th Tide
# Wed 4
# 9:15am
# ▲
# 1.1 m
# 6:56pm
# ▼
# 0.2 m
# ▲
# 5:44am
# ▼
# 6:11pm
# Thu 5
# 9:35am
# ▲
# 1.1 m
# 7:29pm
# ▼
# 0.2 m
# ▲
# 5:44am
# ▼
# 6:12pm
# Fri 6
# 9:54am
# ▲
# 1.1 m
# 8:02pm
# ▼
# 0.2 m
# ▲
# 5:45am
# ▼
# 6:12pm
# Sat 7
# 10:11am
# ▲
# 1.1 m
# 8:36pm
# ▼
# 0.2 m
# ▲
# 5:45am
# ▼
# 6:13pm
# Sun 8
# 10:26am
# ▲
# 1.1 m
# 9:09pm
# ▼
# 0.2 m
# ▲
# 5:46am
# ▼
# 6:13pm
# Mon 9
# 10:39am
# ▲
# 1 m
# 9:39pm
# ▼
# 0.2 m
# ▲
# 5:46am
# ▼
# 6:13pm
# Tue 10
# 10:49am
# ▲
# 1 m
# 10:02pm
# ▼
# 0.3 m
# ▲
# 5:47am
# ▼
# 6:14pm

# %%
from selenium import webdriver
import requests
from bs4 import BeautifulSoup as bs

page = requests.get('https://www.tideschart.com/Indonesia/Jakarta/Weekly/').content
soup = bs(page)
for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    print(fic)

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import Chrome


url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = Options()
chrome_options.add_argument("--headless")
driver = Chrome(options=chrome_options)

#driver = webdriver.Chrome(ChromeDriverManager().install())
driver.maximize_window()
time.sleep(8)
driver.get(url)
time.sleep(10)

soup = BeautifulSoup(driver.page_source, 'lxml')
#driver.close()

#status = soup.find_all('div', {'class': "container-fluid"})
#para = status.find_all('td').get_text
#print(para)
for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    print(fic)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [5], line 18
#      16 driver.maximize_window()
#      17 time.sleep(8)
# ---> 18 driver.get(url).json()
#      19 time.sleep(10)
#      21 soup = BeautifulSoup(driver.page_source, 'lxml')
#
# AttributeError: 'NoneType' object has no attribute 'json'

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
#from webdriver_manager.chrome import ChromeDriverManager
#from selenium.webdriver.chrome.options import Options


url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

#chrome_options = webdriver.ChromeOptions()
#chrome_options.headless = True

'''
options = webdriver.ChromeOptions() 
options.add_argument('--headless')
options.add_argument('--window-size=1920,1080')
options.add_argument('--disable-gpu')
options.add_argument('disable-infobars')
options.add_argument("--disable-extensions")
'''
#driver = webdriver.Chrome(ChromeDriverManager().install(), options=chrome_options)
#driver = webdriver.Chrome(chrome_options=chrome_options)
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')
driver = webdriver.Chrome(chrome_options=chrome_options)

#driver.maximize_window()
time.sleep(2)
driver.get(url)
time.sleep(2)

soup = BeautifulSoup(driver.page_source, 'lxml')
#driver.close()

#status = soup.find_all('div', {'class': "container-fluid"})
#para = status.find_all('td').get_text
#print(para)
for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    print(fic)
driver.quit()
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_304\2723813146.py:30: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# Tide table for Daerah Khusus Ibukota Jakarta this week
# Day
# Tide times for Daerah Khusus Ibukota Jakarta
# 1st Tide
# 2nd Tide
# 3rd Tide
# 4th Tide
# Wed 4
# 9:15am
# ▲
# 1.1 m
# 6:56pm
# ▼
# 0.2 m
# ▲
# 5:44am
# ▼
# 6:11pm
# Thu 5
# 9:35am
# ▲
# 1.1 m
# 7:29pm
# ▼
# 0.2 m
# ▲
# 5:44am
# ▼
# 6:12pm
# Fri 6
# 9:54am
# ▲
# 1.1 m
# 8:02pm
# ▼
# 0.2 m
# ▲
# 5:45am
# ▼
# 6:12pm
# Sat 7
# 10:11am
# ▲
# 1.1 m
# 8:36pm
# ▼
# 0.2 m
# ▲
# 5:45am
# ▼
# 6:13pm
# Sun 8
# 10:26am
# ▲
# 1.1 m
# 9:09pm
# ▼
# 0.2 m
# ▲
# 5:46am
# ▼
# 6:13pm
# Mon 9
# 10:39am
# ▲
# 1 m
# 9:39pm
# ▼
# 0.2 m
# ▲
# 5:46am
# ▼
# 6:13pm
# Tue 10
# 10:49am
# ▲
# 1 m
# 10:02pm
# ▼
# 0.3 m
# ▲
# 5:47am
# ▼
# 6:14pm

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')
driver = webdriver.Chrome(chrome_options=chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')

df_01 = list()

for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    #print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
display(df_01)

df_01.to_csv('testing_tides.csv')
driver.quit()
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_304\1455543472.py:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
#                                                   0    1   \
# 0  Tide table for Daerah Khusus Ibukota Jakarta t...  Day
#
#                                              2         3         4         5   \
# 0  Tide times for Daerah Khusus Ibukota Jakarta  1st Tide  2nd Tide  3rd Tide
#
#          6      7       8  9   ...       74 75   76       77 78     79 80  \
# 0  4th Tide  Wed 4  9:15am  ▲  ...  10:49am  ▲  1 m  10:02pm  ▼  0.3 m  ▲
#
#        81 82      83
# 0  5:47am  ▼  6:14pm
#
# [1 rows x 84 columns]

# %%
display(df_01.iloc[0,1])
# Out:
# 'Day'

# %%
day_1 = df_01.iloc[0,7]
time_tide_1 = df_01.iloc[0,8]
tide_1 = df_01.iloc[0,10]
time_tide_2 = df_01.iloc[0,11]
tide_2 = df_01.iloc[0,13]

# %%
df_02 = []
col_02 =[
    "Hari",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_02 = pd.DataFrame(df_02, columns=col_02)
display(df_02)
# Out:
# Empty DataFrame
# Columns: [Hari, Waktu_tide_1, Tide_1, Waktu_tide_2, Tide_2]
# Index: []

# %%
val_col_02 = [
    df_01.iloc[0,7],
    df_01.iloc[0,8],
    df_01.iloc[0,10],
    df_01.iloc[0,11],
    df_01.iloc[0,13]
]

df_02.loc[len(df_02)] = val_col_02
display(df_02)
# Out:
#     Hari Waktu_tide_1 Tide_1 Waktu_tide_2 Tide_2
# 0  Wed 4       9:15am  1.1 m       6:56pm  0.2 m

# %%
df_02 = []

col_02 =[
    "Hari",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_02 = pd.DataFrame(df_02, columns=col_02)

a = 7
b = 8
c = 10
d = 11
e = 13

x = 1
y = 8
while x < y:
    val_col_02 = [
        df_01.iloc[0,a],
        df_01.iloc[0,b],
        df_01.iloc[0,c],
        df_01.iloc[0,d],
        df_01.iloc[0,e],
    ]
    df_02.loc[len(df_02)] = val_col_02
    x += 1
    a += 11
    b += 11
    c += 11
    d += 11
    e += 11
    

display(df_02)
# Out:
#      Hari Waktu_tide_1 Tide_1 Waktu_tide_2 Tide_2
# 0   Wed 4       9:15am  1.1 m       6:56pm  0.2 m
# 1   Thu 5       9:35am  1.1 m       7:29pm  0.2 m
# 2   Fri 6       9:54am  1.1 m       8:02pm  0.2 m
# 3   Sat 7      10:11am  1.1 m       8:36pm  0.2 m
# 4   Sun 8      10:26am  1.1 m       9:09pm  0.2 m
# 5   Mon 9      10:39am    1 m       9:39pm  0.2 m
# 6  Tue 10      10:49am    1 m      10:02pm  0.3 m

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')
driver = webdriver.Chrome(chrome_options=chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')

df_01 = list()

for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    #print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)

df_02 = []

col_02 =[
    "Hari",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_02 = pd.DataFrame(df_02, columns=col_02)

a = 7
b = 8
c = 10
d = 11
e = 13

x = 1
y = 8
while x < y:
    val_col_02 = [
        df_01.iloc[0,a],
        df_01.iloc[0,b],
        df_01.iloc[0,c],
        df_01.iloc[0,d],
        df_01.iloc[0,e],
    ]
    df_02.loc[len(df_02)] = val_col_02
    x += 1
    a += 11
    b += 11
    c += 11
    d += 11
    e += 11
    

display(df_02)

driver.quit()
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_304\590533413.py:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
#      Hari Waktu_tide_1 Tide_1 Waktu_tide_2 Tide_2
# 0   Wed 4       9:15am  1.1 m       6:56pm  0.2 m
# 1   Thu 5       9:35am  1.1 m       7:29pm  0.2 m
# 2   Fri 6       9:54am  1.1 m       8:02pm  0.2 m
# 3   Sat 7      10:11am  1.1 m       8:36pm  0.2 m
# 4   Sun 8      10:26am  1.1 m       9:09pm  0.2 m
# 5   Mon 9      10:39am    1 m       9:39pm  0.2 m
# 6  Tue 10      10:49am    1 m      10:02pm  0.3 m
