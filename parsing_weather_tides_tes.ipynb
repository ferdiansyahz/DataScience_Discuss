# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://weather.com/id-ID/weather/tenday/l/Kramat+Daerah+Khusus+Ibukota+Jakarta?canonicalCityId=9d5f83a2a29b1f4aa5272fca53aa871b328c5ee66f6882d07480f0a94b37565c#detailIndex5"

r = requests.get(url,verify=False)
soup = BeautifulSoup(r.content, "lxml")

df = pd.DataFrame(columns = [
'Hari_Tanggal',
'temperature_siang',
'temperatur_malam',
'UV_Index',
'Bulan_Terbenam',
'Bulan_Terbit', 
'Fase_Bulan', 
'Matahari_Terbit',
'Matahari_Terbenam',
'Kecepatan_Angin',
'Humidity',
'Perkiraan_Cuaca'
])
print(df)

n=0
for j in range(n,15):

    hari = "detailIndex"+str(j)

    waktu = soup.find(id=hari).find("h3", {"data-testid": "daypartName", "class": "DailyContent--daypartName--3emSU"})

    temp_data_siang = soup.find(id=hari).find("span", {"data-testid": "TemperatureValue", "class": "DetailsSummary--highTempValue--3Oteu"})
    temp_data_malam = soup.find(id=hari).find("span", {"data-testid": "TemperatureValue", "class": "DetailsSummary--lowTempValue--3H-7I"})
    
    humid = soup.find(id=hari).find("span", {"data-testid": "PercentageValue"})

    uv_index = soup.find(id=hari).find("span", {"data-testid": "UVIndexValue", "class": "DetailsTable--value--1q_qD"})
    bulan_terbenam = soup.find(id=hari).find("span", {"data-testid": "MoonsetTime", "class": "DetailsTable--value--1q_qD"})
    bulan_terbit = soup.find(id=hari).find("span", {"data-testid": "MoonriseTime", "class": "DetailsTable--value--1q_qD"})
    Fase_bulan = soup.find(id=hari).find("span", {"data-testid": "moonPhase", "class": "DetailsTable--moonPhrase--2WlTc"})

    Matahari_terbit = soup.find(id=hari).find("span", {"data-testid": "SunriseTime", "class": "DetailsTable--value--1q_qD"})
    Matahari_terbenam = soup.find(id=hari).find("span", {"data-testid": "SunsetTime", "class": "DetailsTable--value--1q_qD"})

    Kecepatan_angin = soup.find(id=hari).find("span", {"data-testid": "Wind", "class": "Wind--windWrapper--3aqXJ DailyContent--value--37sk2"})

    perkiraan = soup.find(id=hari).find("div", {"data-testid": "wxIcon", "class": "DetailsSummary--condition--24gQw"})
    
    #Â°
   
    Mat_ter = str(Matahari_terbit)
    Mat_terben = str(Matahari_terbenam)
    char_1 = '">'
    char_2 = '</'
    Mat_ter = Mat_ter[Mat_ter.find(char_1) + 2 : Mat_ter.find(char_2)]
    Mat_terben = Mat_terben[Mat_terben.find(char_1) + 2 : Mat_terben.find(char_2)]


    df.loc[n] = [waktu.text, 
    temp_data_siang.text[:2], 
    temp_data_malam.text[:2], 
    uv_index.text, 
    bulan_terbenam.text, 
    bulan_terbit.text,
    Fase_bulan.text, 
    Mat_ter, 
    Mat_terben, 
    Kecepatan_angin.text, 
    humid.text, 
    perkiraan.text]
    n = n+1
    
    
print(df)

#df.to_csv('C:/Users/P5CD1/OneDrive/Documents/GitHub/DataScience_Discuss/Parsing_weather.csv', index = False)
# Out:
# c:\Users\P5CD1\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'weather.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# Empty DataFrame
# Columns: [Hari_Tanggal, temperature_siang, temperatur_malam, UV_Index, Bulan_Terbenam, Bulan_Terbit, Fase_Bulan, Matahari_Terbit, Matahari_Terbenam, Kecepatan_Angin, Humidity, Perkiraan_Cuaca]
# Index: []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [1], line 60
#      56     Mat_ter = Mat_ter[Mat_ter.find(char_1) + 2 : Mat_ter.find(char_2)]
#      57     Mat_terben = Mat_terben[Mat_terben.find(char_1) + 2 : Mat_terben.find(char_2)]
# ---> 60     df.loc[n] = [waktu.text,
#      61     temp_data_siang.text[:2],
#      62     temp_data_malam.text[:2],
#      63     uv_index.text,
#      64     bulan_terbenam.text,
#      65     bulan_terbit.text,
#      66     Fase_bulan.text,
#      67     Mat_ter,
#      68     Mat_terben,
#      69     Kecepatan_angin.text,
#      70     humid.text,
#      71     perkiraan.text]
#      72     n = n+1
#      75 print(df)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')
driver = webdriver.Chrome(chrome_options=chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')

df_01 = list()

for el in soup.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic = el.get_text("\n",strip=True)
    #print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)

df_02 = []

col_02 =[
    "Hari",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_02 = pd.DataFrame(df_02, columns=col_02)

a = 7
b = 8
c = 10
d = 11
e = 13

x = 1
y = 8
while x < y:
    val_col_02 = [
        df_01.iloc[0,a],
        df_01.iloc[0,b],
        float(df_01.iloc[0,c]),
        df_01.iloc[0,d],
        float(df_01.iloc[0,e]),
    ]
    df_02.loc[len(df_02)] = val_col_02
    x += 1
    a += 11
    b += 11
    c += 11
    d += 11
    e += 11
    

display(df_02)

driver.quit()
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_19300\3580267772.py:15: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options=chrome_options)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 55
#      50 y = 8
#      51 while x < y:
#      52     val_col_02 = [
#      53         df_01.iloc[0,a],
#      54         df_01.iloc[0,b],
# ---> 55         float(df_01.iloc[0,c]),
#      56         df_01.iloc[0,d],
#      57         float(df_01.iloc[0,e]),
#      58     ]
#      59     df_02.loc[len(df_02)] = val_col_02
#      60     x += 1
#
# ValueError: could not convert string to float: '1.1 m'

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

url = 'https://weather.com/id-ID/weather/tenday/l/Kramat+Daerah+Khusus+Ibukota+Jakarta?canonicalCityId=9d5f83a2a29b1f4aa5272fca53aa871b328c5ee66f6882d07480f0a94b37565c#detailIndex5'
url2 = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)
driver2 = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
driver2.get(url2)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')
soup2 = BeautifulSoup(driver2.page_source, 'lxml')

df_01 = list()
for el in soup.find().find_all("summary",{"class" : "Disclosure--Summary--3GiL4 DaypartDetails--Summary--3Fuya Disclosure--hideBorderOnSummaryOpen--3_ZkO"}):
    fic = el.get_text("\n",strip=True)
    #print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
df_01 = df_01.drop(df_01.columns[[2, 4, 6, 8, 9,11]], axis=1)
display(df_01)
#df_01.to_csv('testing_weather.csv')
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_19300\3594449588.py:17: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options = chrome_options)
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_19300\3594449588.py:18: DeprecationWarning: use options instead of chrome_options
#   driver2 = webdriver.Chrome(chrome_options = chrome_options)
#         0    1    3                      5    7        10
# 0   Kam 05  31°  24°  Badai Petir Terpencar  57%  18 km/j
# 1   Jum 06  31°  24°  Badai Petir Terpencar  39%  23 km/j
# 2   Sab 07  31°  24°  Badai Petir Terpencar  49%  22 km/j
# 3   Min 08  32°  24°            Badai Petir  59%  18 km/j
# 4   Sen 09  31°  23°            Badai Petir  86%  17 km/j
# 5   Sel 10  31°  23°     Badai Petir Petang  61%  16 km/j
# 6   Rab 11  31°  23°            Badai Petir  64%  14 km/j
# 7   Kam 12  31°  23°            Badai Petir  60%  12 km/j
# 8   Jum 13  31°  23°            Badai Petir  60%  12 km/j
# 9   Sab 14  31°  24°            Badai Petir  60%  13 km/j
# 10  Min 15  31°  24°  Badai Petir Terpencar  50%  13 km/j
# 11  Sen 16  31°  24°  Badai Petir Terpencar  56%  14 km/j
# 12  Sel 17  30°  24°            Badai Petir  60%  16 km/j
# 13  Rab 18  30°  24°            Badai Petir  60%  17 km/j

# %%
df_02 = []

col_02 =[
    "Hari",
    "Temperature_siang",
    "Temperature_malam",
    "Prediksi_cuaca",
    "Kemungkinan_hujan",
    "Kecepatan_angin",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_02 = pd.DataFrame(df_02, columns=col_02)
display(df_02)
# Out:
# Empty DataFrame
# Columns: [Hari, Temperature_siang, Temperature_malam, Prediksi_cuaca, Kemungkinan_hujan, Kecepatan_angin, Waktu_tide_1, Tide_1, Waktu_tide_2, Tide_2]
# Index: []

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

url = 'https://weather.com/id-ID/weather/tenday/l/Kramat+Daerah+Khusus+Ibukota+Jakarta?canonicalCityId=9d5f83a2a29b1f4aa5272fca53aa871b328c5ee66f6882d07480f0a94b37565c#detailIndex5'
url2 = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)
driver2 = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
driver2.get(url2)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')
soup2 = BeautifulSoup(driver2.page_source, 'lxml')

df_01 = list()
for el in soup.find().find_all("summary",{"class" : "Disclosure--Summary--3GiL4 DaypartDetails--Summary--3Fuya Disclosure--hideBorderOnSummaryOpen--3_ZkO"}):
    fic = el.get_text("\n",strip=True)
    #print(fic)
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
df_01 = df_01.drop(df_01.columns[[2, 4, 6, 8, 9,11]], axis=1)
df_01 = df_01.drop(labels = [6,7,8,9,10,11,12,13], axis=0)
#display(df_01)

df_all = []

col_all =[
    "Hari",
    "Temperature_siang",
    "Temperature_malam",
    "Prediksi_cuaca",
    "Kemungkinan_hujan",
    "Kecepatan_angin",
    "Waktu_tide_1",
    "Tide_1",
    "Waktu_tide_2",
    "Tide_2"
]
df_all = pd.DataFrame(df_all, columns=col_all)

#df_all = pd.concat([df_all, df_01])
#display(df_all)

####

df_02 = list()

for el in soup2.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic2 = el.get_text("\n",strip=True)
    #print(fic)
    df_02.append(el.get_text("\n",strip=True).split("\n"))

df_02 = pd.DataFrame(df_02)

df_02_temp = []
df_02_temp = pd.DataFrame(df_02_temp, columns = ["0","1","2","3","4"])

a = 7
b = 8
c = 10
d = 11
e = 13

x = 1
y = 8
while x < y:
    val_col_02 = [
        df_02.iloc[0,a],
        df_02.iloc[0,b],
        df_02.iloc[0,c],
        df_02.iloc[0,d],
        df_02.iloc[0,e],
    ]
    df_02_temp.loc[len(df_02_temp)] = val_col_02
    x += 1
    a += 11
    b += 11
    c += 11
    d += 11
    e += 11
    
df_02 = df_02_temp.drop(labels = 0, axis=0)
display(df_02)

df_all["Hari"] = df_01.iloc[:,0]
df_all["Temperature_siang"] = df_01.iloc[:,1]
df_all["Temperature_malam"] = df_01.iloc[:,2]
df_all["Prediksi_cuaca"] = df_01.iloc[:,3]
df_all["Kemungkinan_hujan"] = df_01.iloc[:,4]
df_all["Kecepatan_angin"] = df_01.iloc[:,5]

df_all["Waktu_tide_1"] = df_02.iloc[:,1]
df_all["Tide_1"] = df_02.iloc[:,2]
df_all["Waktu_tide_2"] =df_02.iloc[:,3]
df_all["Tide_2"] = df_02.iloc[:,4]
display(df_all)

driver.quit()
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_19300\2047723804.py:17: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options = chrome_options)
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_19300\2047723804.py:18: DeprecationWarning: use options instead of chrome_options
#   driver2 = webdriver.Chrome(chrome_options = chrome_options)
#         0        1      2        3      4
# 1   Thu 5   9:35am  1.1 m   7:29pm  0.2 m
# 2   Fri 6   9:54am  1.1 m   8:02pm  0.2 m
# 3   Sat 7  10:11am  1.1 m   8:36pm  0.2 m
# 4   Sun 8  10:26am  1.1 m   9:09pm  0.2 m
# 5   Mon 9  10:39am    1 m   9:39pm  0.2 m
# 6  Tue 10  10:49am    1 m  10:02pm  0.3 m
#      Hari Temperature_siang Temperature_malam         Prediksi_cuaca  \
# 0  Kam 05               30°               24°  Badai Petir Terpencar
# 1  Jum 06               30°               24°  Badai Petir Terpencar
# 2  Sab 07               31°               24°  Badai Petir Terpencar
# 3  Min 08               31°               24°  Badai Petir Terpencar
# 4  Sen 09               31°               24°            Badai Petir
# 5  Sel 10               31°               23°     Badai Petir Petang
#
#   Kemungkinan_hujan Kecepatan_angin Waktu_tide_1 Tide_1 Waktu_tide_2 Tide_2
# 0               56%         18 km/j          NaN    NaN          NaN    NaN
# 1               38%         23 km/j       9:35am  1.1 m       7:29pm  0.2 m
# 2               49%         23 km/j       9:54am  1.1 m       8:02pm  0.2 m
# 3               58%         18 km/j      10:11am  1.1 m       8:36pm  0.2 m
# 4               86%         18 km/j      10:26am  1.1 m       9:09pm  0.2 m
# 5               60%         16 km/j      10:39am    1 m       9:39pm  0.2 m

# %%
df_all["Hari"] = df_01.iloc[:,0]
df_all["Temperature_siang"] = df_01.iloc[:,1]
df_all["Temperature_malam"] = df_01.iloc[:,2]
df_all["Prediksi_cuaca"] = df_01.iloc[:,3]
df_all["Kemungkinan_hujan"] = df_01.iloc[:,4]
df_all["Kecepatan_angin"] = df_01.iloc[:,5]

df_all["Waktu_tide_1"] = df_02_temp.iloc[:,1]
df_all["Tide_1"] = df_02_temp.iloc[:,2]
df_all["Waktu_tide_2"] =df_02_temp.iloc[:,3]
df_all["Tide_2"] = df_02_temp.iloc[:,4]
display(df_all)
# Out:
#      Hari Temperature_siang Temperature_malam         Prediksi_cuaca  \
# 0  Kam 05               30°               24°  Badai Petir Terpencar
# 1  Jum 06               30°               24°  Badai Petir Terpencar
# 2  Sab 07               31°               24°  Badai Petir Terpencar
# 3  Min 08               31°               24°  Badai Petir Terpencar
# 4  Sen 09               31°               24°            Badai Petir
# 5  Sel 10               31°               23°     Badai Petir Petang
#
#   Kemungkinan_hujan Kecepatan_angin Waktu_tide_1 Tide_1 Waktu_tide_2 Tide_2  \
# 0               56%         18 km/j          NaN    NaN          NaN    NaN
# 1               38%         23 km/j       9:35am  1.1 m       7:29pm  0.2 m
# 2               49%         23 km/j       9:54am  1.1 m       8:02pm  0.2 m
# 3               58%         18 km/j      10:11am  1.1 m       8:36pm  0.2 m
# 4               86%         18 km/j      10:26am  1.1 m       9:09pm  0.2 m
# 5               60%         16 km/j      10:39am    1 m       9:39pm  0.2 m
#
#   detailIndex0    hari
# 0       Kam 05  Kam 05
# 1       Jum 06  Jum 06
# 2       Sab 07  Sab 07
# 3       Min 08  Min 08
# 4       Sen 09  Sen 09
# 5       Sel 10  Sel 10
