# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd
from pathlib import Path
from IPython.display import display
from sqlalchemy import create_engine
import datetime
import re
import json

url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')


df_01 = list()
'''for el in soup.find("div",{"class" : "card-box card-bottom pb-0"}).find("script").find_all("tide"):
    #fic = text.get_text(",",strip=True)
    #print(fic)
    df_01.append(el.get_text(",{",strip=True).split(","))

df_01 = pd.DataFrame(df_01)'''


import requests
headers =   {'user-agent':'Mozilla/5.0'}

page = requests.get(url, headers=headers)
soup = BeautifulSoup(page.content)
tes1 = soup.find("div",{"class" : "card-box card-bottom pb-0"}).find("script")
#print(soup.select_one("script:contains('title')"))

data = re.search(r"tideData = (.*});", tes1.string , flags=re.S).group(1)
data = json.loads(data)
print(data["data1 "][0]["tide"])

display(df_01)

# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd
from pathlib import Path
from IPython.display import display
from sqlalchemy import create_engine
import datetime
import re
import json

url = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')

import requests, re, json

pattern = re.compile(r'data1 = ({.*})$', re.MULTILINE | re.DOTALL)
script = soup.find("script", text=pattern)

json_string = pattern.search(script.get_text()).group(1)
data = json.loads(json_string)
'''
r = requests.get('https://www.tideschart.com/Indonesia/Jakarta/Weekly/').text
json_data = json.loads(re.search(r"data1 = ({.*})$", r).group(1))

json_data['tide']

const tideData = (data1 = {title: "Daerah Khusus Ibukota Jakarta's tide times for 10 Jan - 16 Jan",unit: "m",
        currentDate: "2023-01-10",
        currentTime: "16:59",
        tide: [{date: "2023-01-09", time: "23:36", value: 0.3 }, { date: "2023-01-10", time: "10:49", value: 1 }, { date: "2023-01-10", time: "22:02", value: 0.3 }, { date: "2023-01-11", time: "10:54", value: 1 }, { date: "2023-01-11", time: "22:15", value: 0.3 }, { date: "2023-01-12", time: "10:47", value: 0.9 }, { date: "2023-01-12", time: "22:13", value: 0.4 }, { date: "2023-01-13", time: "10:16", value: 0.8 }, { date: "2023-01-13", time: "21:44", value: 0.4 }, { date: "2023-01-14", time: "09:10", value: 0.8 }, { date: "2023-01-14", time: "20:33", value: 0.4 }, { date: "2023-01-15", time: "08:02", value: 0.8 }, { date: "2023-01-15", time: "18:36", value: 0.4 }, { date: "2023-01-16", time: "07:31", value: 0.9 }, { date: "2023-01-16", time: "17:36", value: 0.3 }, { date: "2023-01-17", time: "00:10", value: 0.9 }], sun: [{ date: "2023-01-10", sunrise: "05:47", sunset: "18:14" },{ date: "2023-01-11", sunrise: "05:47", sunset: "18:14" },{ date: "2023-01-12", sunrise: "05:48", sunset: "18:14" },{ date: "2023-01-13", sunrise: "05:48", sunset: "18:15" },{ date: "2023-01-14", sunrise: "05:49", sunset: "18:15" },{ date: "2023-01-15", sunrise: "05:49", sunset: "18:15" },{ date: "2023-01-16", sunrise: "05:50", sunset: "18:15" }],
      });

      new VisTideChart({
        id: "tide-chart-container",
        data: tideData,
      });	  '''
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_10960\52803275.py:22: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options = chrome_options)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [15], line 35
#      32 pattern = re.compile(r'data1 = ({.*})$', re.MULTILINE | re.DOTALL)
#      33 script = soup.find("script", text=pattern)
# ---> 35 json_string = pattern.search(script.get_text()).group(1)
#      36 data = json.loads(json_string)
#      37 '''
#      38 r = requests.get('https://www.tideschart.com/Indonesia/Jakarta/Weekly/').text
#      39 json_data = json.loads(re.search(r"data1 = ({.*})$", r).group(1))
#    (...)
#      51         data: tideData,
#      52       });	  '''
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import requests, json
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd
from pathlib import Path
from IPython.display import display
from sqlalchemy import create_engine
import datetime

#r= requests.get("https://www.tideschart.com/Indonesia/Jakarta/Weekly/")
#c= r.content
#soup= BeautifulSoup(c, "html.parser")

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'html.parser')

df_01 = list()
for el in soup.find("div",{"class" : "card-box card-bottom pb-0"}).find_all("script"):
    #fic = el.get_text(",",strip=True)
    fic = el.get_text("{", strip = True)
    
    fic = fic[fic.find('{date:'):]
    sep = ' }],'
    fic = fic.split(sep, 1)[0]
    #print(fic)
    #df_01.append(el.get_text(",{",strip=True).split(","))
    #df_01.append(el.get_text("{", strip = True).split(","))
    #df_01 = pd.DataFrame(fic)
    s = fic
    s = re.findall(r'\d+', s)
    #print(fic)
    print(s)
    #s = json.loads(s)
    #print(type(s))

import numpy as np
array_results=np.array(s)
df_02=pd.DataFrame(array_results.reshape(2, len(s)))
#df_01 = pd.DataFrame(s)
display(df_02)
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_10960\1083704328.py:23: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options = chrome_options)
# ['2023', '01', '09', '23', '36', '0', '3', '2023', '01', '10', '10', '49', '1', '2023', '01', '10', '22', '02', '0', '3', '2023', '01', '11', '10', '54', '1', '2023', '01', '11', '22', '15', '0', '3', '2023', '01', '12', '10', '47', '0', '9', '2023', '01', '12', '22', '13', '0', '4', '2023', '01', '13', '10', '16', '0', '8', '2023', '01', '13', '21', '44', '0', '4', '2023', '01', '14', '09', '10', '0', '8', '2023', '01', '14', '20', '33', '0', '4', '2023', '01', '15', '08', '02', '0', '8', '2023', '01', '15', '18', '36', '0', '4', '2023', '01', '16', '07', '31', '0', '9', '2023', '01', '16', '17', '36', '0', '3', '2023', '01', '17', '00', '10', '0', '9']
# []
# Empty DataFrame
# Columns: []
# Index: [0, 1]
