# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd
from pathlib import Path
from IPython.display import display
from sqlalchemy import create_engine
import datetime

url = 'https://weather.com/id-ID/weather/tenday/l/Kramat+Daerah+Khusus+Ibukota+Jakarta?canonicalCityId=9d5f83a2a29b1f4aa5272fca53aa871b328c5ee66f6882d07480f0a94b37565c#detailIndex5'
url2 = 'https://www.tideschart.com/Indonesia/Jakarta/Weekly/'

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("--no-sandbox")
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'
chrome_options.add_argument(f'user-agent={user_agent}')

driver = webdriver.Chrome(chrome_options = chrome_options)
driver2 = webdriver.Chrome(chrome_options = chrome_options)

time.sleep(0.5)
driver.get(url)
driver2.get(url2)
time.sleep(0.5)

soup = BeautifulSoup(driver.page_source, 'lxml')
soup2 = BeautifulSoup(driver2.page_source, 'lxml')
#Disclosure--Summary--3GiL4 DaypartDetails--Summary--3Fuya Disclosure--hideBorderOnSummaryOpen--3_ZkO
df_01 = list()
for el in soup.find().find_all("details",{"class" : "DaypartDetails--DayPartDetail--2XOOV Disclosure--themeList--1Dz21"}):
    df_01.append(el.get_text("\n",strip=True).split("\n"))

df_01 = pd.DataFrame(df_01)
display(df_01)
# Out:
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_9788\3738585541.py:21: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(chrome_options = chrome_options)
# C:\Users\P5CD1\AppData\Local\Temp\ipykernel_9788\3738585541.py:22: DeprecationWarning: use options instead of chrome_options
#   driver2 = webdriver.Chrome(chrome_options = chrome_options)
#            0    1  2    3                              4   \
# 0   Malam ini   --  /  24°  Scattered Thunderstorms Night
# 1      Rab 11  32°  /  24°        Scattered Thunderstorms
# 2      Kam 12  32°  /  24°        Scattered Thunderstorms
# 3      Jum 13  32°  /  24°        Scattered Thunderstorms
# 4      Sab 14  31°  /  24°        Scattered Thunderstorms
# 5      Min 15  32°  /  24°                  Partly Cloudy
# 6      Sen 16  32°  /  24°        Scattered Thunderstorms
# 7      Sel 17  31°  /  24°                   Thunderstorm
# 8      Rab 18  30°  /  24°                   Thunderstorm
# 9      Kam 19  29°  /  24°                   Thunderstorm
# 10     Jum 20  30°  /  24°        Scattered Thunderstorms
# 11     Sab 21  31°  /  24°                   Thunderstorm
# 12     Min 22  31°  /  24°                   Thunderstorm
# 13     Sen 23  30°  /  24°        Scattered Thunderstorms
# 14     Sel 24  30°  /  24°                   Thunderstorm
#
#                        5     6    7     8    9   ...         48         49  \
# 0   Badai Petir Pagi Buta  Rain  37%  Wind   BD  ...       None       None
# 1      Badai Petir Petang  Rain  38%  Wind   BL  ...  Indeks UV  0 dari 10
# 2      Badai Petir Petang  Rain  40%  Wind  UTL  ...  Indeks UV  0 dari 10
# 3      Badai Petir Petang  Rain  79%  Wind    U  ...  Indeks UV  0 dari 10
# 4      Badai Petir Petang  Rain  41%  Wind   BL  ...  Indeks UV  0 dari 10
# 5        Sebagian Berawan  Rain  24%  Wind    B  ...  Indeks UV  0 dari 10
# 6      Badai Petir Petang  Rain  37%  Wind    B  ...  Indeks UV  0 dari 10
# 7             Badai Petir  Rain  65%  Wind  BBL  ...  Indeks UV  0 dari 10
# 8             Badai Petir  Rain  60%  Wind  BBL  ...  Indeks UV  0 dari 10
# 9             Badai Petir  Rain  60%  Wind  BBL  ...  Indeks UV  0 dari 10
# 10  Badai Petir Terpencar  Rain  57%  Wind  BBL  ...  Indeks UV  0 dari 10
# 11            Badai Petir  Rain  60%  Wind  BBL  ...  Indeks UV  0 dari 10
# 12            Badai Petir  Rain  60%  Wind  BBL  ...  Indeks UV  0 dari 10
# 13  Badai Petir Terpencar  Rain  57%  Wind  BBL  ...  Indeks UV  0 dari 10
# 14            Badai Petir  Rain  60%  Wind  BBL  ...  Indeks UV  0 dari 10
#
#            50            51     52                   53              54  \
# 0        None          None   None                 None            None
# 1   Moon Rise  Bulan Terbit  21.33  Moon Phase - Day 18    Benjol Akhir
# 2   Moon Rise  Bulan Terbit  22.12  Moon Phase - Day 19    Benjol Akhir
# 3   Moon Rise  Bulan Terbit  22.50  Moon Phase - Day 20    Benjol Akhir
# 4   Moon Rise  Bulan Terbit  23.29  Moon Phase - Day 21    Benjol Akhir
# 5   Moon Rise  Bulan Terbit     --  Moon Phase - Day 22  Triwulan Akhir
# 6   Moon Rise  Bulan Terbit   0.11  Moon Phase - Day 23     Sabit Akhir
# 7   Moon Rise  Bulan Terbit   0.57  Moon Phase - Day 24     Sabit Akhir
# 8   Moon Rise  Bulan Terbit   1.48  Moon Phase - Day 25     Sabit Akhir
# 9   Moon Rise  Bulan Terbit   2.45  Moon Phase - Day 26     Sabit Akhir
# 10  Moon Rise  Bulan Terbit   3.49  Moon Phase - Day 27     Sabit Akhir
# 11  Moon Rise  Bulan Terbit   4.56  Moon Phase - Day 29            Baru
# 12  Moon Rise  Bulan Terbit   6.03   Moon Phase - Day 0            Baru
# 13  Moon Rise  Bulan Terbit   7.07   Moon Phase - Day 1      Sabit Awal
# 14  Moon Rise  Bulan Terbit   8.07   Moon Phase - Day 3      Sabit Awal
#
#           55              56     57
# 0       None            None   None
# 1   Moon Set  Bulan Terbenam   9.00
# 2   Moon Set  Bulan Terbenam   9.44
# 3   Moon Set  Bulan Terbenam  10.27
# 4   Moon Set  Bulan Terbenam  11.11
# 5   Moon Set  Bulan Terbenam  11.56
# 6   Moon Set  Bulan Terbenam  12.45
# 7   Moon Set  Bulan Terbenam  13.38
# 8   Moon Set  Bulan Terbenam  14.38
# 9   Moon Set  Bulan Terbenam  15.41
# 10  Moon Set  Bulan Terbenam  16.48
# 11  Moon Set  Bulan Terbenam  17.54
# 12  Moon Set  Bulan Terbenam  18.56
# 13  Moon Set  Bulan Terbenam  19.52
# 14  Moon Set  Bulan Terbenam  20.44
#
# [15 rows x 58 columns]

# %%
df_01 = df_01.drop(df_01.columns[[2, 4, 6, 8, 9,11]], axis=1)
df_01 = df_01.drop(labels = [6,7,8,9,10,11,12,13], axis=0)
display(df_01)
# Out:
#            0    1    3                      5    7        10      12       13  \
# 0   Malam ini   --  24°  Badai Petir Pagi Buta  37%  17 km/j  Sel 10  | Malam
# 1      Rab 11  32°  24°     Badai Petir Petang  38%  15 km/j  Rab 11  | Siang
# 2      Kam 12  32°  24°     Badai Petir Petang  40%  15 km/j  Kam 12  | Siang
# 3      Jum 13  32°  24°     Badai Petir Petang  79%  15 km/j  Jum 13  | Siang
# 4      Sab 14  31°  24°     Badai Petir Petang  41%  14 km/j  Sab 14  | Siang
# 5      Min 15  32°  24°       Sebagian Berawan  24%  18 km/j  Min 15  | Siang
# 14     Sel 24  30°  24°            Badai Petir  60%  19 km/j  Sel 24  | Siang
#
#      14                             15  ...         48         49         50  \
# 0   24°  Scattered Thunderstorms Night  ...       None       None       None
# 1   32°        Scattered Thunderstorms  ...  Indeks UV  0 dari 10  Moon Rise
# 2   32°        Scattered Thunderstorms  ...  Indeks UV  0 dari 10  Moon Rise
# 3   32°        Scattered Thunderstorms  ...  Indeks UV  0 dari 10  Moon Rise
# 4   31°        Scattered Thunderstorms  ...  Indeks UV  0 dari 10  Moon Rise
# 5   32°                  Partly Cloudy  ...  Indeks UV  0 dari 10  Moon Rise
# 14  30°                   Thunderstorm  ...  Indeks UV  0 dari 10  Moon Rise
#
#               51     52                   53              54        55  \
# 0           None   None                 None            None      None
# 1   Bulan Terbit  21.33  Moon Phase - Day 18    Benjol Akhir  Moon Set
# 2   Bulan Terbit  22.12  Moon Phase - Day 19    Benjol Akhir  Moon Set
# 3   Bulan Terbit  22.50  Moon Phase - Day 20    Benjol Akhir  Moon Set
# 4   Bulan Terbit  23.29  Moon Phase - Day 21    Benjol Akhir  Moon Set
# 5   Bulan Terbit     --  Moon Phase - Day 22  Triwulan Akhir  Moon Set
# 14  Bulan Terbit   8.07   Moon Phase - Day 3      Sabit Awal  Moon Set
#
#                 56     57
# 0             None   None
# 1   Bulan Terbenam   9.00
# 2   Bulan Terbenam   9.44
# 3   Bulan Terbenam  10.27
# 4   Bulan Terbenam  11.11
# 5   Bulan Terbenam  11.56
# 14  Bulan Terbenam  20.44
#
# [7 rows x 52 columns]

# %%
df_all = []

col_all =[
    "Datetime",
    "Hari",
    "Temperature_siang_Celcius",
    "Temperature_malam_Celcius",
    "Prediksi_cuaca",
    "Kemungkinan_hujan_persen",
    "Kecepatan_angin_km_per_hour",
    "Waktu_tide_1",
    "Tide_1_meter",
    "Waktu_tide_2",
    "Tide_2_meter"
]
df_all = pd.DataFrame(df_all, columns=col_all)

display(df_all)

# %%
df_02 = list()

for el in soup2.find().find_all("table",{"class" : "table table-hover tidechart mb-4"}):
    fic2 = el.get_text("\n",strip=True)
    #print(fic)
    df_02.append(el.get_text("\n",strip=True).split("\n"))

df_02 = pd.DataFrame(df_02)

df_02_temp = []
df_02_temp = pd.DataFrame(df_02_temp, columns = ["0","1","2","3","4"])
df_02_temp = pd.DataFrame(df_02_temp)

a = 7
b = 8
c = 10
d = 11
e = 13

x = 1
y = 8
while x < y:
    val_col_02 = [
        df_02.iloc[0,a],
        df_02.iloc[0,b],
        df_02.iloc[0,c],
        df_02.iloc[0,d],
        df_02.iloc[0,e],
    ]
    df_02_temp.loc[len(df_02_temp)] = val_col_02
    x += 1
    a += 11
    b += 11
    c += 11
    d += 11
    e += 11
    
df_02 = df_02_temp.drop(labels = 0, axis=0)
df_02.index = range(len(df_02))
#df_02_temp.rename(df_02_temp.iloc[0], axis=0, inplace=True)
#df_02 = df_02_temp.drop(df_02_temp.index[0], axis = 0, inplace=True)
#display(df_02)

df_all["Hari"] = df_01.iloc[:,0]
df_all["Temperature_siang_Celcius"] = df_01.iloc[:,1]
df_all["Temperature_malam_Celcius"] = df_01.iloc[:,2]
df_all["Prediksi_cuaca"] = df_01.iloc[:,3]
df_all["Kemungkinan_hujan_persen"] = df_01.iloc[:,4]
df_all["Kecepatan_angin_km_per_hour"] = df_01.iloc[:,5]

df_all["Waktu_tide_1"] = df_02.iloc[:,1]
df_all["Tide_1_meter"] = df_02.iloc[:,2]
df_all["Waktu_tide_2"] =df_02.iloc[:,3]
df_all["Tide_2_meter"] = df_02.iloc[:,4]
#display(df_all)


df_all['Temperature_siang_Celcius'] = df_all.Temperature_siang_Celcius.str.findall('([-+]?\d*\.?\d+)')
df_all['Temperature_malam_Celcius'] = df_all.Temperature_malam_Celcius.str.findall('([-+]?\d*\.?\d+)')
df_all['Kemungkinan_hujan_persen'] = df_all.Kemungkinan_hujan_persen.str.findall('([-+]?\d*\.?\d+)')
df_all['Kecepatan_angin_km_per_hour'] = df_all.Kecepatan_angin_km_per_hour.str.findall('([-+]?\d*\.?\d+)')
df_all['Tide_1_meter'] = df_all.Tide_1_meter.str.findall('([-+]?\d*\.?\d+)')
df_all['Tide_2_meter'] = df_all.Tide_2_meter.str.findall('([-+]?\d*\.?\d+)')

#df_all.apply(pd.Series.explode)
#df_all.explode()
#display(df_all)
df_all = df_all.apply(pd.Series.explode)
#display(df_all)
df_all = df_all.drop([df_all.index[1], df_all.index[2], df_all.index[3], df_all.index[4], df_all.index[5]])
#df_all['id'] = 1
df_all.Temperature_siang_Celcius = pd.to_numeric(df_all.Temperature_siang_Celcius, errors='coerce')
df_all.Temperature_malam_Celcius = pd.to_numeric(df_all.Temperature_malam_Celcius, errors='coerce')
df_all.Kemungkinan_hujan_persen = pd.to_numeric(df_all.Kemungkinan_hujan_persen, errors='coerce')
df_all.Kecepatan_angin_km_per_hour = pd.to_numeric(df_all.Kecepatan_angin_km_per_hour, errors='coerce')
df_all.Tide_1_meter = pd.to_numeric(df_all.Tide_1_meter, errors='coerce')
df_all.Tide_2_meter = pd.to_numeric(df_all.Tide_2_meter, errors='coerce')
df_all['Datetime'] = datetime.datetime.now()
display(df_all)

my_file = Path("data_weather_tides_harian.csv")
if my_file.is_file():
    df_csv_01 = pd.read_csv("data_weather_tides_harian.csv")
    #df_csv_01 = pd.concat([df_csv_01, df_all])
    result = pd.concat([df_csv_01, df_all]).drop_duplicates(subset=["Hari"], keep="last")
    #df_csv_01.merge(df_all, how='outer', on='Hari')
    result.to_csv("data_weather_tides_harian.csv", index = False)
else :
    df_all.to_csv("data_weather_tides_harian.csv", index = False)

from sqlalchemy.orm import sessionmaker
# Credentials to database connection
hostname="localhost"
dbname="workshop"
uname="root"
pwd="sanjii123"


# Create SQLAlchemy engine to connect to MySQL Database
engine = create_engine("mysql+pymysql://{user}:{pw}@{host}/{db}"
				.format(host=hostname, db=dbname, user=uname, pw=pwd))

session = sessionmaker(bind=engine)()

# Convert dataframe to sql table                                   
df_all.to_sql('parsing_cuaca_gelombang_current', engine, if_exists='replace', index=False)
df_all.to_sql('parsing_cuaca_gelombang_hystorian', engine, if_exists='append', index=False)


engine.dispose()
session.close()
driver.quit()
